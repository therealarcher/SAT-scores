# %% [markdown]
# # Read in the data

# %%
import pandas as pd
import numpy
import re

data_files = [
    "ap_2010.csv",
    "class_size.csv",
    "demographics.csv",
    "graduation.csv",
    "hs_directory.csv",
    "sat_results.csv"
]

data = {}

for f in data_files:
    d = pd.read_csv("schools/{0}".format(f))
    data[f.replace(".csv", "")] = d

# %% [markdown]
# # Read in the surveys

# %%
all_survey = pd.read_csv("schools/survey_all.txt", delimiter="\t", encoding='windows-1252')
d75_survey = pd.read_csv("schools/survey_d75.txt", delimiter="\t", encoding='windows-1252')
survey = pd.concat([all_survey, d75_survey], axis=0)

survey["DBN"] = survey["dbn"]

survey_fields = [
    "DBN", 
    "rr_s", 
    "rr_t", 
    "rr_p", 
    "N_s", 
    "N_t", 
    "N_p", 
    "saf_p_11", 
    "com_p_11", 
    "eng_p_11", 
    "aca_p_11", 
    "saf_t_11", 
    "com_t_11", 
    "eng_t_11", 
    "aca_t_11", 
    "saf_s_11", 
    "com_s_11", 
    "eng_s_11", 
    "aca_s_11", 
    "saf_tot_11", 
    "com_tot_11", 
    "eng_tot_11", 
    "aca_tot_11",
]
survey = survey.loc[:,survey_fields]
data["survey"] = survey

# %% [markdown]
# # Add DBN columns

# %%
data["hs_directory"]["DBN"] = data["hs_directory"]["dbn"]

def pad_csd(num):
    string_representation = str(num)
    if len(string_representation) > 1:
        return string_representation
    else:
        return "0" + string_representation
    
data["class_size"]["padded_csd"] = data["class_size"]["CSD"].apply(pad_csd)
data["class_size"]["DBN"] = data["class_size"]["padded_csd"] + data["class_size"]["SCHOOL CODE"]

# %% [markdown]
# # Convert columns to numeric

# %%
cols = ['SAT Math Avg. Score', 'SAT Critical Reading Avg. Score', 'SAT Writing Avg. Score']
for c in cols:
    data["sat_results"][c] = pd.to_numeric(data["sat_results"][c], errors="coerce")

data['sat_results']['sat_score'] = data['sat_results'][cols[0]] + data['sat_results'][cols[1]] + data['sat_results'][cols[2]]

def find_lat(loc):
    coords = re.findall("\(.+, .+\)", loc)
    lat = coords[0].split(",")[0].replace("(", "")
    return lat

def find_lon(loc):
    coords = re.findall("\(.+, .+\)", loc)
    lon = coords[0].split(",")[1].replace(")", "").strip()
    return lon

data["hs_directory"]["lat"] = data["hs_directory"]["Location 1"].apply(find_lat)
data["hs_directory"]["lon"] = data["hs_directory"]["Location 1"].apply(find_lon)

data["hs_directory"]["lat"] = pd.to_numeric(data["hs_directory"]["lat"], errors="coerce")
data["hs_directory"]["lon"] = pd.to_numeric(data["hs_directory"]["lon"], errors="coerce")

# %% [markdown]
# # Condense datasets

# %%
class_size = data["class_size"]
class_size = class_size[class_size["GRADE "] == "09-12"]
class_size = class_size[class_size["PROGRAM TYPE"] == "GEN ED"]

class_size = class_size.groupby("DBN").agg(numpy.mean)
class_size.reset_index(inplace=True)
data["class_size"] = class_size

data["demographics"] = data["demographics"][data["demographics"]["schoolyear"] == 20112012]

data["graduation"] = data["graduation"][data["graduation"]["Cohort"] == "2006"]
data["graduation"] = data["graduation"][data["graduation"]["Demographic"] == "Total Cohort"]

# %% [markdown]
# # Convert AP scores to numeric

# %%
cols = ['AP Test Takers ', 'Total Exams Taken', 'Number of Exams with scores 3 4 or 5']

for col in cols:
    data["ap_2010"][col] = pd.to_numeric(data["ap_2010"][col], errors="coerce")

# %% [markdown]
# # Combine the datasets

# %%
combined = data["sat_results"]

combined = combined.merge(data["ap_2010"], on="DBN", how="left")
combined = combined.merge(data["graduation"], on="DBN", how="left")

to_merge = ["class_size", "demographics", "survey", "hs_directory"]

for m in to_merge:
    combined = combined.merge(data[m], on="DBN", how="inner")

combined = combined.fillna(combined.mean())
combined = combined.fillna(0)

# %% [markdown]
# # Add a school district column for mapping

# %%
def get_first_two_chars(dbn):
    return dbn[0:2]

combined["school_dist"] = combined["DBN"].apply(get_first_two_chars)

# %% [markdown]
# # Find correlations

# %%
correlations = combined.corr()
correlations = correlations["sat_score"]
print(correlations)
# Out:
# SAT Critical Reading Avg. Score         0.986820
# SAT Math Avg. Score                     0.972643
# SAT Writing Avg. Score                  0.987771
# sat_score                               1.000000
# AP Test Takers                          0.523140
# Total Exams Taken                       0.514333
# Number of Exams with scores 3 4 or 5    0.463245
# Total Cohort                            0.325144
# CSD                                     0.042948
# NUMBER OF STUDENTS / SEATS FILLED       0.394626
# NUMBER OF SECTIONS                      0.362673
# AVERAGE CLASS SIZE                      0.381014
# SIZE OF SMALLEST CLASS                  0.249949
# SIZE OF LARGEST CLASS                   0.314434
# SCHOOLWIDE PUPIL-TEACHER RATIO               NaN
# schoolyear                                   NaN
# fl_percent                                   NaN
# frl_percent                            -0.722225
# total_enrollment                        0.367857
# ...

# %% [markdown]
# # Plotting survey correlations

# %%
# Remove DBN since it's a unique identifier, not a useful numerical value for correlation.
survey_fields.remove("DBN")

# %%
# %matplotlib inline
combined.corr()["sat_score"][survey_fields].plot.bar()

# %% [markdown]
# Fairly strong correlations between SAT scores and the following:
# -  "n_s" - number of student responents
# -  "n_p" - number of parent respondents
# -  "saf_p_11" - safety and respect score based on parents responses
# -  "saf_s_11" - safety and respect score based on student responses
# -  "aca_s_11" - Academic expectations score based on student responses
# -  "saf_tot_11" - Safety and Respect total score
#
# "n_s" and "n_p" are related to enrollment, and thus may be a reason as to the correlation.
#
# "saf_p_11" and "saf_s_11" could be correlated due to the perception of safety by both students and teachers.  ie a safer place to learn is likely a better place to learn.
#
# "aca_s_11" is likely correlated due to students knowing where they stand related to SATs.  One interesting finding is that teachers show a reduced ability to predict success, and parents even less.

# %%
combined.plot.scatter("saf_s_11","sat_score")

# %% [markdown]
# After further investigation, it appears as though there is a  weak positive correlation between SAT scores and Safety (as perceived by students).  The main cluster of schools is around 6.5 on the safety scale, and then flares out both ways, with a slight tendency to have higher SAT scores with greater safety, but not in every case.  This said, very low safety scores (below 6.5) don't have any high SAT scores (over 1500).  So safety appears to have a stronger correlation upto about 6.5, and then the results are less dependable.  It seems fair to conclude that below average safety results in lower SAT scores on average.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

districts = combined.groupby("school_dist").agg(numpy.mean)
districts.reset_index(inplace=True)
print(districts.head())
# Out:
#   school_dist  SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# 0          01                       441.833333           473.333333
# 1          02                       426.619092           444.186256
# 2          03                       428.529851           437.997512
# 3          04                       402.142857           416.285714
# 4          05                       427.159915           438.236674
#
#    SAT Writing Avg. Score    sat_score  AP Test Takers   Total Exams Taken  \
# 0              439.333333  1354.500000       116.681090         173.019231
# 1              424.832836  1295.638184       128.908454         201.516827
# 2              426.915672  1293.443035       156.183494         244.522436
# 3              405.714286  1224.142857       129.016484         183.879121
# 4              419.666098  1285.062687        85.722527         115.725275
#
#    Number of Exams with scores 3 4 or 5  Total Cohort  CSD    ...      \
# ...

# %%
m = Basemap(
    projection='merc', 
    llcrnrlat=40.496044, 
    urcrnrlat=40.915256, 
    llcrnrlon=-74.255735, 
    urcrnrlon=-73.700272,
    resolution='i'
)
m.drawmapboundary(fill_color='gray')
m.drawcoastlines(color='black', linewidth=.4)
m.drawrivers(color='green', linewidth=.4)

longitudes = districts["lon"].tolist()
latitudes = districts["lat"].tolist()
m.scatter(longitudes, latitudes, s=50, zorder = 2, latlon = True, c=districts["saf_s_11"], cmap = "summer")
plt.show()

# %%
race_cat = ["white_per", "asian_per", "black_per", "hispanic_per"]

combined.corr()["sat_score"][race_cat].plot.bar()

# %% [markdown]
# It appears as though high percentages of white and asian studnets in a school corresponded to higher SAT scores while schools with higher black and hispanic percentages scored higher.  Though this may mean that white and asian people may do better in an SAT test, it also can mean that schools with higher percentages of black and hispanic students may not have adequate teaching facilities and maybe less funding.

# %%
combined.plot.scatter("sat_score", "hispanic_per")

# %% [markdown]
# This scatter plot doesn't show much conclusiveness or correlation.  Most of the schools with the highest SAT scores also had the lowest Hispanic percentages.

# %%
#print(combined.columns)
print(combined[combined["hispanic_per"] > 95]["SCHOOL NAME"])
# Out:
# 44                         MANHATTAN BRIDGES HIGH SCHOOL
# 82      WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL
# 89     GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND M...
# 125                  ACADEMY FOR LANGUAGE AND TECHNOLOGY
# 141                INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# 176     PAN AMERICAN INTERNATIONAL HIGH SCHOOL AT MONROE
# 253                            MULTICULTURAL HIGH SCHOOL
# 286               PAN AMERICAN INTERNATIONAL HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# The schools listed above are more geared towards newer immigrants learning english.  This explains why SAT scores would be lower.

# %%
print(combined[(combined["hispanic_per"] < 10) & (combined["sat_score"] > 1800)]["SCHOOL NAME"])
# Out:
# 37                                STUYVESANT HIGH SCHOOL
# 151                         BRONX HIGH SCHOOL OF SCIENCE
# 187                       BROOKLYN TECHNICAL HIGH SCHOOL
# 327    QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK CO...
# 356                  STATEN ISLAND TECHNICAL HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# These science and technology schools tend to require advanced testing for entry, and also get extra funding.  The low hispanic percentage could be for multiple reasons from socioeconomic to cultural factors determining school choices by students and their parents.

# %%
m_f = ["male_per", "female_per"]
combined.corr()["sat_score"][m_f].plot.bar()

# %% [markdown]
# In the above, no correlation is particularly strong, but there is a weak positive correlation between SAT scores and schools with a higher female percentage and a weak negative correlation with SAT results and male dominant percentage population in schools.

# %%
combined.plot.scatter("sat_score", "female_per")

# %% [markdown]
# There doesn't appear to be a strong correlation between the female percentages in school and SAT scores in the above scatter plot.

# %%
print(combined[(combined["female_per"] > 60) & (combined["sat_score"] > 1700)]["SCHOOL NAME"])
# Out:
# 5                         BARD HIGH SCHOOL EARLY COLLEGE
# 26                         ELEANOR ROOSEVELT HIGH SCHOOL
# 60                                    BEACON HIGH SCHOOL
# 61     FIORELLO H. LAGUARDIA HIGH SCHOOL OF MUSIC & A...
# 302                          TOWNSEND HARRIS HIGH SCHOOL
# Name: SCHOOL NAME, dtype: object

# %% [markdown]
# These schools appear to be very selective and have high academic standards.

# %% [markdown]
# # AP Tests and SAT scores

# %%
combined["ap_per"] = (combined['AP Test Takers '] / combined["total_enrollment"])
combined.plot.scatter("ap_per", "sat_score")

# %% [markdown]
# It doesn't look like a very strong correlation between AP test takers and total SAT scores as per the scatter plot above.
